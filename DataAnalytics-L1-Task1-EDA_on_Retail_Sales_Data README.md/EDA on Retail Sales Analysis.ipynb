# %%
import os

path = r"C:\Users\HP\Documents\Data Analytics -L1-EDA on Retail Sales Data\EDA on Retail_Sales_Analysis.xlsx"

print(os.path.exists(path))
# Out:
# True

# %%
import os

print(os.listdir(r"C:\Users\HP\Documents"))
# Out:
# ['1-a162f3f3-83bd-45c1-9b13-2dbac7636a73.pdf', '5.pdf', '6.pdf', 'Application_form_VTL20260342.docx', 'Application_form_VTL20260342.pdf', 'Custom Office Templates', 'Customer_Behaviour_Dashboard.pbix', 'Data Analytics -L1-EDA on Retail Sales Data', 'desktop.ini', 'Dhivya Pan card.pdf', 'Ecommerce projject', 'ecommercesql.txt', 'LF LOGO.pdf', 'My Music', 'My Pictures', 'My Videos', 'OneNote Notebooks', 'Pan Card.pdf', 'Pictures - Shortcut.lnk', 'Power BI Desktop', 'scan.jpeg', 'S_Dhivya_Internship_Resume_Table.docx', 'S_Sangeetha_Resume.docx', 'vidhya.jpeg', 'WhatsApp Image 2026-02-19 at 9.00.10 PM.jpeg', 'WhatsApp Image 2026-02-19 at 9.00.11 PM.jpeg', 'WhatsApp Image 2026-02-21 at 7.45.46 PM.jpeg', 'WhatsApp Image 2026-02-21 at 7.53.36 PM.jpeg', 'WhatsApp Image 2026-02-23 at 7.23.49 PM.jpeg', 'WhatsApp Image 2026-02-26 at 6.41.53 PM.jpeg', 'WhatsApp Image 2026-02-26 at 6.41.54 PM.jpeg', 'WhatsApp Image 2026-05-25 at 1.01.54 PM.jpeg', 'WhatsApp Image 2026-05-25 at 1.04.32 PM.jpeg', 'W
# ...

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\HP\Documents\Data Analytics -L1-EDA on Retail Sales Data

# %%
print(os.listdir())
# Out:
# ['EDA on Retail Sales Analysis.ipynb', 'EDA on Retail_Sales_Analysis.pbix', 'EDA on Retail_Sales_Analysis.sql', 'EDA on Retail_Sales_Analysis.xlsx']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel(r"C:\Users\HP\Documents\Data Analytics -L1-EDA on Retail Sales Data\EDA on Retail_Sales_Analysis.xlsx")
print(df.head())
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'review_score',
#        'review_count', 'sales_month_1', 'sales_month_2', 'sales_month_3',
#        'sales_month_4', 'sales_month_5', 'sales_month_6', 'sales_month_7',
#        'sales_month_8', 'sales_month_9', 'sales_month_10', 'sales_month_11',
#        'sales_month_12'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      1000 non-null   int64
#  1   product_name    1000 non-null   object
#  2   category        1000 non-null   object
#  3   price           1000 non-null   float64
#  4   review_score    1000 non-null   float64
#  5   review_count    1000 non-null   int64
#  6   sales_month_1   1000 non-null   int64
#  7   sales_month_2   1000 non-null   int64
#  8   sales_month_3   1000 non-null   int64
#  9   sales_month_4   1000 non-null   int64
#  10  sales_month_5   1000 non-null   int64
#  11  sales_month_6   1000 non-null   int64
#  12  sales_month_7   1000 non-null   int64
#  13  sales_month_8   1000 non-null   int64
#  14  sales_month_9   1000 non-null   int64
#  15  sales_month_10  1000 non-null   int64
#  16  sales_month_11  1000 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         product_id        price  review_score  review_count  sales_month_1  \
# count  1000.000000  1000.000000   1000.000000   1000.000000    1000.000000
# mean    500.500000   247.677130      3.027600    526.506000     498.306000
# std     288.819436   144.607983      1.171243    282.269932     289.941478
# min       1.000000     7.290000      1.000000      1.000000       0.000000
# 25%     250.750000   121.810000      2.000000    283.750000     245.500000
# 50%     500.500000   250.920000      3.100000    543.000000     507.500000
# 75%     750.250000   373.435000      4.000000    772.000000     740.750000
# max    1000.000000   499.860000      5.000000    999.000000    1000.000000
#
#        sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# count    1000.000000    1000.000000    1000.000000    1000.000000
# mean      507.661000     506.739000     503.823000     487.194000
# std       285.992689     294.010873     286.645567     287.844324
# ...

# %%
df.isnull().sum()
# Out:
# product_id        0
# product_name      0
# category          0
# price             0
# review_score      0
# review_count      0
# sales_month_1     0
# sales_month_2     0
# sales_month_3     0
# sales_month_4     0
# sales_month_5     0
# sales_month_6     0
# sales_month_7     0
# sales_month_8     0
# sales_month_9     0
# sales_month_10    0
# sales_month_11    0
# sales_month_12    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      1000 non-null   int64
#  1   product_name    1000 non-null   object
#  2   category        1000 non-null   object
#  3   price           1000 non-null   float64
#  4   review_score    1000 non-null   float64
#  5   review_count    1000 non-null   int64
#  6   sales_month_1   1000 non-null   int64
#  7   sales_month_2   1000 non-null   int64
#  8   sales_month_3   1000 non-null   int64
#  9   sales_month_4   1000 non-null   int64
#  10  sales_month_5   1000 non-null   int64
#  11  sales_month_6   1000 non-null   int64
#  12  sales_month_7   1000 non-null   int64
#  13  sales_month_8   1000 non-null   int64
#  14  sales_month_9   1000 non-null   int64
#  15  sales_month_10  1000 non-null   int64
#  16  sales_month_11  1000 non-null   int64
# ...

# %%
sales_columns = [col for col in df.columns if col.startswith('sales_month_')]

total_sales = df[sales_columns].sum().sum()

print("Total Sales:", total_sales)
# Out:
# Total Sales: 6019912

# %%
sales_columns = [col for col in df.columns if col.startswith('sales_month_')]

df["Sales"] = df[sales_columns].sum(axis=1)

print(df[["product_name", "Sales"]].head())
# Out:
#   product_name  Sales
# 0    Product_1   6421
# 1    Product_2   6027
# 2    Product_3   5580
# 3    Product_4   5022
# 4    Product_5   6094

# %%
total_sales = df["Sales"].sum()
print("Total Sales:", total_sales)
# Out:
# Total Sales: 6019912

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("RagavanSangeetha@0930")
host = "localhost"
port = "3306"
database = "ecommerce_sales"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)
